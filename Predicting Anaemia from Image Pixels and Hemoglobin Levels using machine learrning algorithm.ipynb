# %%
import numpy as np
import pandas as  pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
file_path="C:/Users/LENOVO/Downloads/output (1).csv"
df = pd.read_csv(file_path)

# %%
df.head(6)
# Out:
#    Number Sex  %Red Pixel  %Green pixel  %Blue pixel    Hb Anaemic
# 0       1   M     43.2555       30.8421      25.9025   6.3     Yes
# 1       2   F     45.6033       28.1900      26.2067  13.5      No
# 2       3  F      45.0107       28.9677      26.0215  11.7      No
# 3       4   F     44.5398       28.9899      26.4703  13.5      No
# 4       5  M      43.2870       30.6972      26.0158  12.4      No
# 5       6   M     45.0994       27.9645      26.9361  16.2      No

# %%
df.tail()
# Out:
#      Number Sex  %Red Pixel  %Green pixel  %Blue pixel    Hb Anaemic
# 99      100  F      49.9999       29.2860      20.7141  14.5     Yes
# 100     101  M      42.2324       30.6757      27.0919   6.3     Yes
# 101     102   F     45.6064       31.9084      22.4852  12.7      No
# 102     103  M      45.2095       29.2769      25.5136  13.4      No
# 103     104   F     43.5706       29.8094      26.6199  12.2      No

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Number        104 non-null    int64
#  1   Sex           104 non-null    object
#  2   %Red Pixel    104 non-null    float64
#  3   %Green pixel  104 non-null    float64
#  4   %Blue pixel   104 non-null    float64
#  5   Hb            104 non-null    float64
#  6   Anaemic       104 non-null    object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 5.8+ KB

# %%
df.shape
# Out:
# (104, 7)

# %%
df.info
# Out:
# <bound method DataFrame.info of      Number Sex  %Red Pixel  %Green pixel  %Blue pixel    Hb Anaemic
# 0         1   M     43.2555       30.8421      25.9025   6.3     Yes
# 1         2   F     45.6033       28.1900      26.2067  13.5      No
# 2         3  F      45.0107       28.9677      26.0215  11.7      No
# 3         4   F     44.5398       28.9899      26.4703  13.5      No
# 4         5  M      43.2870       30.6972      26.0158  12.4      No
# ..      ...  ..         ...           ...          ...   ...     ...
# 99      100  F      49.9999       29.2860      20.7141  14.5     Yes
# 100     101  M      42.2324       30.6757      27.0919   6.3     Yes
# 101     102   F     45.6064       31.9084      22.4852  12.7      No
# 102     103  M      45.2095       29.2769      25.5136  13.4      No
# 103     104   F     43.5706       29.8094      26.6199  12.2      No
#
# [104 rows x 7 columns]>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Number        104 non-null    int64
#  1   Sex           104 non-null    object
#  2   %Red Pixel    104 non-null    float64
#  3   %Green pixel  104 non-null    float64
#  4   %Blue pixel   104 non-null    float64
#  5   Hb            104 non-null    float64
#  6   Anaemic       104 non-null    object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 5.8+ KB

# %%
df.describe()
# Out:
#            Number  %Red Pixel  %Green pixel  %Blue pixel          Hb
# count  104.000000  104.000000    104.000000   104.000000  104.000000
# mean    52.500000   45.654175     28.875507    25.470325   12.150962
# std     30.166206    2.816294      1.554275     1.984671    2.512957
# min      1.000000   38.796800     25.140300    19.541300    2.800000
# 25%     26.750000   43.911375     27.871300    24.896425   10.650000
# 50%     52.500000   45.385350     28.948750    25.953200   12.600000
# 75%     78.250000   46.968325     29.887275    26.721600   14.000000
# max    104.000000   54.647800     32.368100    29.841400   16.300000

# %%
df.isnull()
# Out:
#      Number    Sex  %Red Pixel  %Green pixel  %Blue pixel     Hb  Anaemic
# 0     False  False       False         False        False  False    False
# 1     False  False       False         False        False  False    False
# 2     False  False       False         False        False  False    False
# 3     False  False       False         False        False  False    False
# 4     False  False       False         False        False  False    False
# ..      ...    ...         ...           ...          ...    ...      ...
# 99    False  False       False         False        False  False    False
# 100   False  False       False         False        False  False    False
# 101   False  False       False         False        False  False    False
# 102   False  False       False         False        False  False    False
# 103   False  False       False         False        False  False    False
#
# [104 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# Number          0
# Sex             0
# %Red Pixel      0
# %Green pixel    0
# %Blue pixel     0
# Hb              0
# Anaemic         0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Number', 'Sex', '%Red Pixel', '%Green pixel', '%Blue pixel', 'Hb',
#        'Anaemic'],
#       dtype='object')

# %%
df.drop('Number',axis=1, inplace=True)

# %%
print(df)
# Out:
#     Sex  %Red Pixel  %Green pixel  %Blue pixel    Hb Anaemic
# 0     M     43.2555       30.8421      25.9025   6.3     Yes
# 1     F     45.6033       28.1900      26.2067  13.5      No
# 2    F      45.0107       28.9677      26.0215  11.7      No
# 3     F     44.5398       28.9899      26.4703  13.5      No
# 4    M      43.2870       30.6972      26.0158  12.4      No
# ..   ..         ...           ...          ...   ...     ...
# 99   F      49.9999       29.2860      20.7141  14.5     Yes
# 100  M      42.2324       30.6757      27.0919   6.3     Yes
# 101   F     45.6064       31.9084      22.4852  12.7      No
# 102  M      45.2095       29.2769      25.5136  13.4      No
# 103   F     43.5706       29.8094      26.6199  12.2      No
#
# [104 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['Sex', '%Red Pixel', '%Green pixel', '%Blue pixel', 'Hb', 'Anaemic'], dtype='object')

# %%
plt.figure(figsize=(20,18))
sns.heatmap(df.corr(numeric_only=True), annot=True,linewidths=.5, cmap="Blues")
# Out:
# <Axes: >

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 99     False
# 100    False
# 101    False
# 102    False
# 103    False
# Length: 104, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Sex'].unique()
# Out:
# array(['M', 'F', 'F ', 'M '], dtype=object)

# %%
gender = []

for i in df['Sex']:
  if i == 'M':
    i = 'Male'
    gender.append(i)
  else:
    i = 'Female'
    gender.append(i)

df['Sex'] = gender

# %%
df.head(3)
# Out:
#       Sex  %Red Pixel  %Green pixel  %Blue pixel    Hb Anaemic
# 0    Male     43.2555       30.8421      25.9025   6.3     Yes
# 1  Female     45.6033       28.1900      26.2067  13.5      No
# 2  Female     45.0107       28.9677      26.0215  11.7      No

# %%
df['Sex'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize = (10, 6))

# %%
sns.boxplot(data = df, x = 'Sex', y = '%Red Pixel', color = 'r')
# Out:
# <Axes: xlabel='Sex', ylabel='%Red Pixel'>

# %%
sns.violinplot(data = df, x = 'Sex', y = '%Blue pixel', color = 'blue')
# Out:
# <Axes: xlabel='Sex', ylabel='%Blue pixel'>

# %%
sns.boxplot(data = df, x = 'Sex', y = '%Green pixel', color = 'g')
# Out:
# <Axes: xlabel='Sex', ylabel='%Green pixel'>

# %%
sns.regplot(data = df, x = '%Red Pixel', y = '%Green pixel', color = 'y')
# Out:
# <Axes: xlabel='%Red Pixel', ylabel='%Green pixel'>

# %%
sns.lineplot(data = df, x = '%Red Pixel', y = '%Blue pixel', color = 'pink')
# Out:
# <Axes: xlabel='%Red Pixel', ylabel='%Blue pixel'>

# %%
sns.scatterplot(data = df, x = '%Blue pixel', y = '%Green pixel', color = 'black')
# Out:
# <Axes: xlabel='%Blue pixel', ylabel='%Green pixel'>

# %%
df.head(3)
# Out:
#       Sex  %Red Pixel  %Green pixel  %Blue pixel    Hb Anaemic
# 0    Male     43.2555       30.8421      25.9025   6.3     Yes
# 1  Female     45.6033       28.1900      26.2067  13.5      No
# 2  Female     45.0107       28.9677      26.0215  11.7      No

# %%
df.tail(3)
# Out:
#         Sex  %Red Pixel  %Green pixel  %Blue pixel    Hb Anaemic
# 101  Female     45.6064       31.9084      22.4852  12.7      No
# 102  Female     45.2095       29.2769      25.5136  13.4      No
# 103  Female     43.5706       29.8094      26.6199  12.2      No

# %%
df = pd.get_dummies(df, columns = ['Sex', 'Anaemic'], drop_first = True)

# %%
df.head(3)
# Out:
#    %Red Pixel  %Green pixel  %Blue pixel    Hb  Sex_Male  Anaemic_Yes
# 0     43.2555       30.8421      25.9025   6.3      True         True
# 1     45.6033       28.1900      26.2067  13.5     False        False
# 2     45.0107       28.9677      26.0215  11.7     False        False

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
y = df['Anaemic_Yes']
x = df.drop('Anaemic_Yes', axis = 1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.7, random_state = 26)

# %%
rf = RandomForestClassifier(n_estimators=100, max_depth = 4, min_samples_split= 4)
model = rf.fit(x_train, y_train)
score = model.score(x_test, y_test)
print(f'Score: {score}')
# Out:
# Score: 0.96875

# %%
print(score*100,"%")
# Out:
# 96.875 %

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

rf = RandomForestClassifier()

param_grid = {
    'n_estimators': [50, 100, 200],
    'max_features': ['sqrt', 'log2'],  
    'max_depth': [4, 6, 8, 10, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False]
}

grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=5, n_jobs=-1, verbose=2)
grid_search.fit(x_train, y_train)

best_params = grid_search.best_params_
best_score = grid_search.best_score_

print(f'Best Parameters: {best_params}')
print(f'Best Scores: {best_score}')
# Out:
# Fitting 5 folds for each of 540 candidates, totalling 2700 fits
