# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
file_path="C:/Users/LENOVO/Downloads/archive (5)/dataset_heath - pre processed data 1.csv"
df = pd.read_csv(file_path)

# %%
df.head(5)
# Out:
#   India/States/UTs  Survey   Area  \
# 0            state  survey   area
# 1            India  NFHS-4  Total
# 2            India  NFHS-4  Rural
# 3            India  NFHS-4  Urban
# 4            India  NFHS-3  Total
#
#   Population And Household Profile - Population (Female) Age 6 Years And Above Who Ever Attended School (%)  \
# 0                                           a6school
# 1                                               68.8
# 2                                                 63
# 3                                               80.6
# 4                                               58.3
#
#   Population And Household Profile - Population Below Age 15 Years (%)  \
# 0                                                a15
# 1                                               28.6
# 2                                               30.5
# 3                                               24.9
# 4                                               34.9
#
# ...

# %%
df.tail()
# Out:
#     India/States/UTs  Survey   Area  \
# 144      Lakshadweep  NFHS-3  Total
# 145       Puducherry  NFHS-4  Total
# 146       Puducherry  NFHS-4  Rural
# 147       Puducherry  NFHS-4  Urban
# 148       Puducherry  NFHS-3  Total
#
#     Population And Household Profile - Population (Female) Age 6 Years And Above Who Ever Attended School (%)  \
# 144                                                NaN
# 145                                               81.4
# 146                                               77.7
# 147                                                 83
# 148                                                NaN
#
#     Population And Household Profile - Population Below Age 15 Years (%)  \
# 144                                                NaN
# 145                                               23.7
# 146                                               23.4
# 147                                               23.9
# 148                                                NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Columns: 192 entries, India/States/UTs to Note Of : Tobacco Use And Alcohol Consumption Among Adults (Age 15-49 Years) - Men Who Tried To Stop Smoking Or Using Tobacco In Any Other Form (During The Past 12 Months) %
# dtypes: float64(82), object(110)
# memory usage: 223.6+ KB

# %%
df.shape
# Out:
# (149, 192)

# %%
df.isnull()
# Out:
#      India/States/UTs  Survey   Area  \
# 0               False   False  False
# 1               False   False  False
# 2               False   False  False
# 3               False   False  False
# 4               False   False  False
# ..                ...     ...    ...
# 144             False   False  False
# 145             False   False  False
# 146             False   False  False
# 147             False   False  False
# 148             False   False  False
#
#      Population And Household Profile - Population (Female) Age 6 Years And Above Who Ever Attended School (%)  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ..                                                 ...
# 144                                               True
# ...

# %%
df.isnull().sum()
# Out:
# India/States/UTs                                                                                                                                                                     0
# Survey                                                                                                                                                                               0
# Area                                                                                                                                                                                 0
# Population And Household Profile - Population (Female) Age 6 Years And Above Who Ever Attended School (%)                                                                           10
# Population And Household Profile - Population Below Age 15 Years (%)                                                                                                                10
# ...

# %%
df.isnull().sum()
# Out:
# India/States/UTs                                                                                                                                                                     0
# Survey                                                                                                                                                                               0
# Area                                                                                                                                                                                 0
# Population And Household Profile - Population (Female) Age 6 Years And Above Who Ever Attended School (%)                                                                           10
# Population And Household Profile - Population Below Age 15 Years (%)                                                                                                                10
# ...

# %%
df.describe()
# Out:
#        Marriage And Fertility - Women Age 20-24 Years Married Before Age 18 Years (%)  \
# count                                         136.000000
# mean                                           23.227941
# std                                            13.399324
# min                                             0.700000
# 25%                                            13.100000
# 50%                                            20.500000
# 75%                                            30.900000
# max                                            65.200000
#
#        Marriage And Fertility - Men Age 25-29 Years Married Before Age 21 Years (%)  \
# count                                         132.000000
# mean                                           21.184848
# std                                            11.969666
# min                                             0.000000
# 25%                                            13.275000
# ...

# %%
df.columns
# Out:
# Index(['India/States/UTs', 'Survey', 'Area',
#        'Population And Household Profile - Population (Female) Age 6 Years And Above Who Ever Attended School (%)',
#        'Population And Household Profile - Population Below Age 15 Years (%)',
#        'Population And Household Profile - Sex Ratio Of The Total Population (Females Per 1000 Males)',
#        'Population And Household Profile - Sex Ratio At Birth For Children Born In The Last Five Years (Females Per 1000 Males)',
#        'Population And Household Profile - Children Under Age 5 Years Whose Birth Was Registered (%)',
#        'Population And Household Profile - Households With Electricity (%)',
#        'Population And Household Profile - Households With An Improved Drinking-Water Source (%)',
#        ...
#        'Note Of : Women's Empowerment And Gender Based Violence (Age 15-49 Years) - Ever-Married Women Who Have Ever Experienced Spousal Violence (%)',
# ...

# %%
plt.figure(figsize=(10,18))
sns.heatmap(df.corr(numeric_only=True), annot=True,linewidths=.5, cmap="Blues")
# Out:
# <Axes: >

# %%
df.duplicated
# Out:
# <bound method DataFrame.duplicated of     India/States/UTs  Survey   Area  \
# 0              state  survey   area
# 1              India  NFHS-4  Total
# 2              India  NFHS-4  Rural
# 3              India  NFHS-4  Urban
# 4              India  NFHS-3  Total
# ..               ...     ...    ...
# 144      Lakshadweep  NFHS-3  Total
# 145       Puducherry  NFHS-4  Total
# 146       Puducherry  NFHS-4  Rural
# 147       Puducherry  NFHS-4  Urban
# 148       Puducherry  NFHS-3  Total
#
#     Population And Household Profile - Population (Female) Age 6 Years And Above Who Ever Attended School (%)  \
# 0                                             a6school
# 1                                                 68.8
# 2                                                   63
# 3                                                 80.6
# 4                                                 58.3
# ..                                                 ...
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# India/States/UTs                                                                                                                                                                     0
# Survey                                                                                                                                                                               0
# Area                                                                                                                                                                                 0
# Population And Household Profile - Population (Female) Age 6 Years And Above Who Ever Attended School (%)                                                                           10
# Population And Household Profile - Population Below Age 15 Years (%)                                                                                                                10
# ...

# %%
df = pd.DataFrame(df)

# %%
def replace_nan_with_mode(column):
    mode = column.mode()
    if not mode.empty:
        return column.fillna(mode[0])
    return column

# %%
df = df.apply(replace_nan_with_mode)

# %%
# Out:
# India/States/UTs                                                                                                                                                                   0
# Survey                                                                                                                                                                             0
# Area                                                                                                                                                                               0
# Population And Household Profile - Population (Female) Age 6 Years And Above Who Ever Attended School (%)                                                                          0
# Population And Household Profile - Population Below Age 15 Years (%)                                                                                                               0
# ...

# %%
df.isnull().sum()
# Out:
# India/States/UTs                                                                                                                                                                   0
# Survey                                                                                                                                                                             0
# Area                                                                                                                                                                               0
# Population And Household Profile - Population (Female) Age 6 Years And Above Who Ever Attended School (%)                                                                          0
# Population And Household Profile - Population Below Age 15 Years (%)                                                                                                               0
# ...

# %%
obj_list=df.select_dtypes("object").columns
print(obj_list)
# Out:
# Index(['India/States/UTs', 'Survey', 'Area',
#        'Population And Household Profile - Population (Female) Age 6 Years And Above Who Ever Attended School (%)',
#        'Population And Household Profile - Population Below Age 15 Years (%)',
#        'Population And Household Profile - Sex Ratio Of The Total Population (Females Per 1000 Males)',
#        'Population And Household Profile - Sex Ratio At Birth For Children Born In The Last Five Years (Females Per 1000 Males)',
#        'Population And Household Profile - Children Under Age 5 Years Whose Birth Was Registered (%)',
#        'Population And Household Profile - Households With Electricity (%)',
#        'Population And Household Profile - Households With An Improved Drinking-Water Source (%)',
#        ...
#        'Note Of : Women's Empowerment And Gender Based Violence (Age 15-49 Years) - Ever-Married Women Who Have Ever Experienced Spousal Violence (%)',
# ...

# %%
for obj in obj_list:
  print(obj)
# Out:
# India/States/UTs
# Survey
# Area
# Population And Household Profile - Population (Female) Age 6 Years And Above Who Ever Attended School (%)
# Population And Household Profile - Population Below Age 15 Years (%)
# Population And Household Profile - Sex Ratio Of The Total Population (Females Per 1000 Males)
# Population And Household Profile - Sex Ratio At Birth For Children Born In The Last Five Years (Females Per 1000 Males)
# Population And Household Profile - Children Under Age 5 Years Whose Birth Was Registered (%)
# Population And Household Profile - Households With Electricity (%)
# Population And Household Profile - Households With An Improved Drinking-Water Source (%)
# Population And Household Profile - Households Using Improved Sanitation Facility (%)
# Population And Household Profile - Households Using Clean Fuel For Cooking (%)
# Population And Household Profile - Households Using Iodized Salt (%)
# ...

# %%
from sklearn.preprocessing import LabelEncoder
for obj in obj_list:
 df[obj]=LabelEncoder().fit_transform(df[obj])
 df

# %%
df
# Out:
#      India/States/UTs  Survey  Area  \
# 0                  37       2     3
# 1                  14       1     1
# 2                  14       1     0
# 3                  14       1     2
# 4                  14       0     1
# ..                ...     ...   ...
# 144                19       0     1
# 145                27       1     1
# 146                27       1     0
# 147                27       1     2
# 148                27       0     1
#
#      Population And Household Profile - Population (Female) Age 6 Years And Above Who Ever Attended School (%)  \
# 0                                                  113
# 1                                                   38
# 2                                                   24
# 3                                                   78
# 4                                                   17
# ..                                                 ...
# 144                                                 24
# ...

# %%
labels = df['India/States/UTs']
sizes = df['Area']
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.show()

# %%
labels = df['India/States/UTs']
sizes = df['Population And Household Profile - Population Below Age 15 Years (%)']
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.show()

# %%
labels = df['India/States/UTs']
sizes = df['Population And Household Profile - Children Under Age 5 Years Whose Birth Was Registered (%)']
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.show()

# %%
X=df.drop('Population And Household Profile - Population Below Age 15 Years (%)',axis=1)
Y=df['Population And Household Profile - Population Below Age 15 Years (%)']
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3)
X_train
# Out:
#      India/States/UTs  Survey  Area  \
# 83                  9       1     2
# 139                 8       1     2
# 71                 34       1     2
# 96                 15       0     1
# 23                 11       1     2
# ..                ...     ...   ...
# 25                 12       1     1
# 119                33       1     2
# 65                 32       1     1
# 51                 26       1     2
# 34                 17       1     0
#
#      Population And Household Profile - Population (Female) Age 6 Years And Above Who Ever Attended School (%)  \
# 83                                                  84
# 139                                                 91
# 71                                                  53
# 96                                                  14
# 23                                                  86
# ..                                                 ...
# 25                                                  43
# ...

# %%
Y_train
# Out:
# 83     25
# 139     4
# 71     46
# 96     65
# 23     19
#        ..
# 25     40
# 119     5
# 65     27
# 51     18
# 34     27
# Name: Population And Household Profile - Population Below Age 15 Years (%), Length: 104, dtype: int32

# %%
X_test
# Out:
#      India/States/UTs  Survey  Area  \
# 103                23       1     2
# 41                 20       1     1
# 62                 31       1     0
# 84                  9       0     1
# 55                 28       1     2
# 29                 16       1     1
# 128                 0       0     1
# 17                  6       1     1
# 111                25       1     2
# 43                 20       1     2
# 95                 15       1     2
# 138                 8       1     0
# 63                 31       1     2
# 42                 20       1     0
# 110                25       1     0
# 59                 29       1     2
# 73                 36       1     1
# 126                 0       1     0
# 134                 7       1     0
# 70                 34       1     0
# 26                 12       1     0
# 100                22       0     1
# 11                  3       1     2
# 131                 5       1     2
# 66                 32       1     0
# ...

# %%
Y_test
# Out:
# 103    41
# 41     54
# 62     21
# 84     44
# 55     14
# 29     69
# 128    20
# 17     47
# 111    52
# 43     35
# 95     17
# 138    29
# 63      9
# 42     62
# 110    70
# 59     36
# 73     29
# 126    22
# 134    67
# 70     80
# 26     42
# 100    71
# 11     11
# 131    20
# 66     28
# 92     48
# 90     27
# 38      1
# 48     56
# 33     23
# 108    79
# 120    52
# 13     87
# 117    24
# 9      54
# 80     86
# 78     67
# 18     53
# 10     61
# 104    91
# 141    13
# 61     16
# 106    72
# 101    82
# 145    19
# Name: Population And Household Profile - Population Below Age 15 Years (%), dtype: int32

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
X = df.iloc[:, :-1].values  
y = df.iloc[:, -1].values   
sc = StandardScaler()
X = sc.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
n_features = X_train.shape[1]
n_classes = len(set(y_train))
n_components = min(n_features, n_classes - 1)
lda = LDA(n_components=n_components)
X_train_lda = lda.fit_transform(X_train, y_train)
X_test_lda = lda.transform(X_test)
classifier = LogisticRegression(random_state=42)
classifier.fit(X_train_lda, y_train)
y_pred = classifier.predict(X_test_lda)
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy * 100:.2f}%')
# Out:
# Accuracy: 97.78%

# %%
plt.scatter(
    X_train[:, 0], X_train[:, 1],
    c=y_train,
    cmap='rainbow',
    alpha=0.7, edgecolors='b'
)

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
X = df.iloc[:, :-1].values  
y = df.iloc[:, -1].values   
sc = StandardScaler()
X = sc.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
pca = PCA(n_components=2)  # Number of components can be adjusted
X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)
classifier = LogisticRegression(random_state=42)
classifier.fit(X_train_pca, y_train)
y_pred = classifier.predict(X_test_pca)
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy * 100:.2f}%')
# Out:
# Accuracy: 97.78%

# %%
plt.scatter(
    X_train[:, 0], X_train[:, 1],
    c=y_train,
    cmap='rainbow',
    alpha=0.7, edgecolors='b'
)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis as QDA
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import pandas as pd
X = df.iloc[:, :-1].values  
y = df.iloc[:, -1].values   
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)
qda = QDA()
qda.fit(X_train, y_train)
y_pred = qda.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print(f'Accuracy: {accuracy * 100:.2f}%')
print('Confusion Matrix:')
print(conf_matrix)
print('Classification Report:')
print(class_report)
# Out:
# Accuracy: 60.00%
# Confusion Matrix:
# [[26 18]
#  [ 0  1]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.59      0.74        44
#            1       0.05      1.00      0.10         1
#
#     accuracy                           0.60        45
#    macro avg       0.53      0.80      0.42        45
# weighted avg       0.98      0.60      0.73        45
